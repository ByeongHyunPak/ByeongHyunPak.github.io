# %% [markdown]
# # DenseAV Demonstration Notebook
#
# > ⚠️ Change your collab runtime to T4 GPU before running this notebook
#
# In this notebook we will walk through how to load, visualize, and work with our catalog of pre-trained models.

# %% [markdown]
# ## Set up Google Collab
# > ⚠️ Skip this section if you are not on Google Collab

# %%
# !git clone https://github.com/mhamilton723/DenseAV
# Out:
# fatal: destination path 'DenseAV' already exists and is not an empty directory.

# %%
# !pip install av
# Out:
# Requirement already satisfied: av in /usr/local/lib/python3.11/dist-packages (14.3.0)

# %%
import os
os.chdir("DenseAV/")

# %%
# !pip install -e .
# Out:
# Obtaining file:///content/DenseAV
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (from denseav==0.1.0) (2.6.0+cu124)
# Requirement already satisfied: kornia in /usr/local/lib/python3.11/dist-packages (from denseav==0.1.0) (0.8.0)
# Requirement already satisfied: omegaconf in /usr/local/lib/python3.11/dist-packages (from denseav==0.1.0) (2.3.0)
# Requirement already satisfied: pytorch-lightning in /usr/local/lib/python3.11/dist-packages (from denseav==0.1.0) (2.5.1.post0)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (from denseav==0.1.0) (0.21.0+cu124)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from denseav==0.1.0) (4.67.1)
# Requirement already satisfied: torchmetrics in /usr/local/lib/python3.11/dist-packages (from denseav==0.1.0) (1.7.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from denseav==0.1.0) (1.6.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from denseav==0.1.0) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from denseav==0.1.0) (3.10.0)
# Requirement already satisfied: timm==0.4.12 in /usr/local/lib/python3.11/dist-packages (from denseav==0.1.0) (0.4.12)
# Requirement already satisfied: moviepy in /usr/local/lib/python3.11/dist-packages (from denseav==0.1.0) (1.0.3)
# Requirement already satisfied: hydra-core in /usr/local/lib/python3.11/dist-packages (from denseav==0.1.0) (1.3.2)
# Requirement already satisfied: peft==0.5.0 in /usr/local/lib/python3.11/dist-packages (from denseav==0.1.0) (0.5.0)
# Requirement already satisfied: av in /usr/local/lib/python3.11/dist-packages (from denseav==0.1.0) (14.3.0)
# Requirement already satisfied: audioread in /usr/local/lib/python3.11/dist-packages (from denseav==0.1.0) (3.0.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from peft==0.5.0->denseav==0.1.0) (24.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from peft==0.5.0->denseav==0.1.0) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from peft==0.5.0->denseav==0.1.0) (6.0.2)
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (from peft==0.5.0->denseav==0.1.0) (4.51.3)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.11/dist-packages (from peft==0.5.0->denseav==0.1.0) (1.6.0)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.11/dist-packages (from peft==0.5.0->denseav==0.1.0) (0.5.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch->denseav==0.1.0) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch->denseav==0.1.0) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch->denseav==0.1.0) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch->denseav==0.1.0) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch->denseav==0.1.0) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->denseav==0.1.0) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->denseav==0.1.0) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->denseav==0.1.0) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch->denseav==0.1.0) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch->denseav==0.1.0) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch->denseav==0.1.0) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch->denseav==0.1.0) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch->denseav==0.1.0) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch->denseav==0.1.0) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch->denseav==0.1.0) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch->denseav==0.1.0) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->denseav==0.1.0) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->denseav==0.1.0) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch->denseav==0.1.0) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch->denseav==0.1.0) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch->denseav==0.1.0) (1.3.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.11/dist-packages (from hydra-core->denseav==0.1.0) (4.9.3)
# Requirement already satisfied: kornia_rs>=0.1.0 in /usr/local/lib/python3.11/dist-packages (from kornia->denseav==0.1.0) (0.1.8)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->denseav==0.1.0) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->denseav==0.1.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->denseav==0.1.0) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->denseav==0.1.0) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->denseav==0.1.0) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->denseav==0.1.0) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->denseav==0.1.0) (2.9.0.post0)
# Requirement already satisfied: decorator<5.0,>=4.0.2 in /usr/local/lib/python3.11/dist-packages (from moviepy->denseav==0.1.0) (4.4.2)
# Requirement already satisfied: requests<3.0,>=2.8.1 in /usr/local/lib/python3.11/dist-packages (from moviepy->denseav==0.1.0) (2.32.3)
# Requirement already satisfied: proglog<=1.0.0 in /usr/local/lib/python3.11/dist-packages (from moviepy->denseav==0.1.0) (0.1.11)
# Requirement already satisfied: imageio<3.0,>=2.5 in /usr/local/lib/python3.11/dist-packages (from moviepy->denseav==0.1.0) (2.37.0)
# Requirement already satisfied: imageio-ffmpeg>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from moviepy->denseav==0.1.0) (0.6.0)
# Requirement already satisfied: lightning-utilities>=0.10.0 in /usr/local/lib/python3.11/dist-packages (from pytorch-lightning->denseav==0.1.0) (0.14.3)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->denseav==0.1.0) (1.15.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->denseav==0.1.0) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->denseav==0.1.0) (3.6.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]>=2022.5.0->pytorch-lightning->denseav==0.1.0) (3.11.15)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from lightning-utilities>=0.10.0->pytorch-lightning->denseav==0.1.0) (75.2.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->denseav==0.1.0) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0,>=2.8.1->moviepy->denseav==0.1.0) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0,>=2.8.1->moviepy->denseav==0.1.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0,>=2.8.1->moviepy->denseav==0.1.0) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3.0,>=2.8.1->moviepy->denseav==0.1.0) (2025.1.31)
# Requirement already satisfied: huggingface-hub>=0.21.0 in /usr/local/lib/python3.11/dist-packages (from accelerate->peft==0.5.0->denseav==0.1.0) (0.30.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch->denseav==0.1.0) (3.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers->peft==0.5.0->denseav==0.1.0) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers->peft==0.5.0->denseav==0.1.0) (0.21.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning->denseav==0.1.0) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning->denseav==0.1.0) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning->denseav==0.1.0) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning->denseav==0.1.0) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning->denseav==0.1.0) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning->denseav==0.1.0) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning->denseav==0.1.0) (1.20.0)
# Installing collected packages: denseav
#   Attempting uninstall: denseav
#     Found existing installation: denseav 0.1.0
#     Uninstalling denseav-0.1.0:
#       Successfully uninstalled denseav-0.1.0
#   Running setup.py develop for denseav
# Successfully installed denseav-0.1.0

# %% [markdown]
# ## Import dependencies and load a pretrained DenseAV Model

# %%
from os.path import join

import torch
import torchvision
import torchvision.transforms as T
from PIL import Image
from torchaudio.functional import resample

from denseav.plotting import plot_attention_video, plot_2head_attention_video, plot_feature_video, display_video_in_notebook
from denseav.shared import norm, crop_to_divisor, blur_dim

# %%
model_name = "sound_and_language"
video_path = "samples/puppies.mp4"
result_dir = "results"
load_size = 224
plot_size = 224

# %%
model = torch.hub.load('mhamilton723/DenseAV', model_name).cuda()
# Out:
# Using cache found in /root/.cache/torch/hub/mhamilton723_DenseAV_main
# INFO:pytorch_lightning.utilities.migration.utils:Lightning automatically upgraded your loaded checkpoint from v1.9.4 to v2.5.1.post0. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint https:/marhamilresearch4.blob.core.windows.net/denseav-public/hub/denseav_2head.ckpt`
# Using cache found in /root/.cache/torch/hub/facebookresearch_dino_main
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# trainable params: 147,456 || all params: 21,817,728 || trainable%: 0.6758540577644016

# %% [markdown]
# ## Load a sample video and prepare it for DenseAV

# %%
original_frames, audio, info = torchvision.io.read_video(video_path, pts_unit='sec')
sample_rate = 16000

if info["audio_fps"] != sample_rate:
    audio = resample(audio, info["audio_fps"], sample_rate)
audio = audio[0].unsqueeze(0)

img_transform = T.Compose([
    T.Resize(load_size, Image.BILINEAR),
    lambda x: crop_to_divisor(x, 8),
    lambda x: x.to(torch.float32) / 255,
    norm])

frames = torch.cat([img_transform(f.permute(2, 0, 1)).unsqueeze(0) for f in original_frames], axis=0)

plotting_img_transform = T.Compose([
    T.Resize(plot_size, Image.BILINEAR),
    lambda x: crop_to_divisor(x, 8),
    lambda x: x.to(torch.float32) / 255])

frames_to_plot = plotting_img_transform(original_frames.permute(0, 3, 1, 2))

# %% [markdown]
# ## Use DenseAV to obtain dense AV-aligned features

# %%
with torch.no_grad():
    audio_feats = model.forward_audio({"audio": audio.cuda()})
    audio_feats = {k: v.cpu() for k,v in audio_feats.items()}
    image_feats = model.forward_image({"frames": frames.unsqueeze(0).cuda()}, max_batch_size=2)
    image_feats = {k: v.cpu() for k,v in image_feats.items()}


    sim_by_head = model.sim_agg.get_pairwise_sims(
        {**image_feats, **audio_feats},
        raw=False,
        agg_sim=False,
        agg_heads=False
    ).mean(dim=-2).cpu()

    sim_by_head = blur_dim(sim_by_head, window=3, dim=-1)
    print(sim_by_head.shape)
# Out:
# torch.Size([181, 2, 14, 14, 33])

# %%
info["video_fps"] = int(info["video_fps"])

# %% [markdown]
# ## Visualize Cross-Modal Attention

# %%
plot_attention_video(
    sim_by_head,
    frames_to_plot,
    audio,
    info["video_fps"],
    sample_rate,
    "results/attention.mp4")
display_video_in_notebook("results/attention.mp4")
# Out:
# >> 30
# Moviepy - Building video results/attention.mp4.
# MoviePy - Writing audio in attentionTEMP_MPY_wvf_snd.mp3
# MoviePy - Done.
# Moviepy - Writing video results/attention.mp4
# Moviepy - Done !
# Moviepy - video ready results/attention.mp4
#   <video width=400 controls>
#         <source src="data:video/mp4;base64,..." type="video/mp4">
#   </video>

# %% [markdown]
# ## Visualize Cross Modal Attention by Head to Disentangle Sound and Language

# %%
if model_name == "sound_and_language":
  plot_2head_attention_video(
      sim_by_head,
      frames_to_plot,
      audio,
      info["video_fps"],
      sample_rate,
      "results/2head_attention.mp4")
  display_video_in_notebook("results/2head_attention.mp4")

# %% [markdown]
# ## Plot Deep Features

# %%
plot_feature_video(
    image_feats["image_feats"].cpu(),
    audio_feats['audio_feats'].cpu(),
    frames_to_plot,
    audio,
    info["video_fps"],
    sample_rate,
    "results/visual_features.mp4",
    "results/audio_features.mp4",
)
display_video_in_notebook("results/visual_features.mp4")
display_video_in_notebook("results/audio_features.mp4")
